# %% [markdown]
# Day 10 — Methods in Python (Simple Explanation)
# What is a Method?
#
# A method is a function that belongs to a class.
#
# You already know functions:
#
# def greet():
#     print("Hello")
#
# When a function is written inside a class, it is called a method.
#
# class Student:
#     def greet(self):
#         print("Hello")
#
# Here, greet() is a method.
#
# Why Do We Use Methods?
#
# Methods define the behavior of an object.
#
# Think of a real bank account:
#
# Data (Attributes):
#
# Account Holder Name
# Balance
#
# Actions (Methods):
#
# Deposit Money
# Withdraw Money
# Check Balance
# class BankAccount:
#     def deposit(self):
#         pass
#
#     def withdraw(self):
#         pass
#
#     def check_balance(self):
#         pass
# Understanding self
#
# Every method inside a class usually has self as its first parameter.
#
# class Student:
#     def greet(self):
#         print("Hello")
#
# self refers to the current object.
#
# Example:
#
# class Student:
#     def __init__(self, name):
#         self.name = name
#
#     def introduce(self):
#         print("My name is", self.name)
#
# s1 = Student("Dhruv")
# s1.introduce()
#
# Output:
#
# My name is Dhruv
#
# Python automatically passes s1 as self.
#
# Internally:
#
# Student.introduce(s1)
# Method Accessing Attributes
#
# Methods can use object attributes through self.
#
# class Student:
#     def __init__(self, name):
#         self.name = name
#
#     def show_name(self):
#         print(self.name)
#
# s1 = Student("Dhruv")
# s1.show_name()
#
# Output:
#
# Dhruv
# Method Modifying Attributes
#
# Methods can also change attribute values.
#
# class BankAccount:
#     def __init__(self):
#         self.balance = 0
#
#     def deposit(self, amount):
#         self.balance += amount
#
# account = BankAccount()
#
# account.deposit(500)
#
# print(account.balance)
#
# Output:
#
# 500
#
# The method changed the object's balance.
#
# Types of Methods You'll Commonly Use
# 1. Instance Methods
#
# Most common type.
#
# class Student:
#     def greet(self):
#         print("Hello")
#
# Works with object data using self.
#
# 2. Constructor Method (__init__)
#
# Runs automatically when an object is created.
#
# class Student:
#     def __init__(self, name):
#         self.name = name
# s1 = Student("Dhruv")
#
# __init__() runs automatically.
#
# Complete Example
# class BankAccount:
#
#     def __init__(self, balance=0):
#         self.balance = balance
#
#     def deposit(self, amount):
#         self.balance += amount
#         print("Deposited:", amount)
#
#     def withdraw(self, amount):
#         if amount <= self.balance:
#             self.balance -= amount
#             print("Withdrawn:", amount)
#         else:
#             print("Insufficient Balance")
#
#     def check_balance(self):
#         print("Current Balance:", self.balance)
#
# account = BankAccount()
#
# account.deposit(1000)
# account.withdraw(300)
# account.check_balance()
#
# Output:
#
# Deposited: 1000
# Withdrawn: 300
# Current Balance: 700
# Variable vs Method
# Variable	Method
# Stores data	Performs action
# Noun	Verb
# name, age, balance	deposit(), withdraw(), show()
# Represents state	Represents behavior
#
# Example:
#
# class Student:
#     def __init__(self):
#         self.name = "Dhruv"   # Variable
#
#     def greet(self):         # Method
#         print("Hello")
# Quick Interview Answer
# What is a Method?
#
# A method is a function defined inside a class that performs actions related to an object and can access object data using self.
#
# Difference Between Variable and Method?
#
# A variable stores data, while a method performs actions or operations on that data.

# %%
# Create a Car class with a start() method.
class Car:
    def __init__(self):
        self.start = False
    def starti(self):
        self.start = True
        print("Car Started")
c1 = Car()
c1.starti()
# Out:
# Car Started

# %%
# Create a Student class with a show_details() method.
class Student:
    def __init__(self , name , standard):
        self.name = name
        self.standard = standard
    def show_details(self):
        print(f"Student Name : {self.name}\nStudent Standard : {self.standard}")
s1 = Student("Dhruv","12th")
s1.show_details()
# Out:
# Student Name : Dhruv
# Student Standard : 12th

# %%
# Create a Calculator class with methods:

# add()
# subtract()
class Calculator:
    def __init__(self):
        self.a = int(input("Enter first number : " ))
        self.b = int(input("Enter second number : " ))
    def add(self):
            print(f"Addition is : {self.a + self.b}")
    def sub(self):
        print(f"Subtraction is : {self.a - self.b}")
c1 = Calculator()
c1.add()
c1.sub()
# Out:
# Enter first number :  10
# Enter second number :  5
# Addition is : 15
# Subtraction is : 5

# %%
# Create a BankAccount class with:

# deposit()
# withdraw()
# check_balance()

class BankAccount:
    def __init__(self , balance):
        self.balance  = balance
    def deposit(self,deposit):
        self.balance += deposit
    def withdraw(self,acc):
        if self.balance > acc:
            self.balance -= acc
        else:
            print("Insufficient Balance " )
    def check_balance(self):
        print("Your Balance is : " , self.balance)
ba = BankAccount(500)
ba.deposit(500)
ba.check_balance()
ba.withdraw(200)
ba.check_balance()
# Out:
# Your Balance is :  1000
# Your Balance is :  800

# %%
# Build a menu-driven ATM Simulator using methods only.
class Atm:
    def __init__(self,account_no , balance):
        self.account_no = account_no
        self.balance  = balance
        self.menu()
    def check_balance(self):
        print(f"Your Balance is : {self.balance}")
    def withdraw(self):
        n = int(input("Enter the Amount in Rs: " ))
        if self.balance > n :
            self.balance = self.balance - n
            print(f"{n} Rs Debited To your account ")
        else:
            print("Insufficient Balance")
    def deposite(self):
        n = int(input("Enter the Amount Deposite "))
        self.balance += n
        print(f"{n} Rs. Credited to your account")
    def menu(self):
        while True:
            try:
                print("Welcome to ATM Simulator")
                choice = int(input("Choose : \n    1.Check Balance\n    2.Withdraw\n    3.Deposite\n    4.Exit\nEnter Choice : "))
                if choice == 1:
                    self.check_balance()
                elif choice == 2:
                    self.withdraw()
                elif choice == 3:
                    self.deposite()
                elif choice == 4:
                    break
                else:
                    print("Please Enter a Valid Choice[1-4]")
            except ValueError:
                print("Enter Valid Number ")
            
a = Atm(123,10000)
# Out:
# Welcome to ATM Simulator
# Choose :
#     1.Check Balance
#     2.Withdraw
#     3.Deposite
#     4.Exit
# Enter Choice :  1
# Your Balance is : 10000
# Welcome to ATM Simulator
# Choose :
#     1.Check Balance
#     2.Withdraw
#     3.Deposite
#     4.Exit
# Enter Choice :  2
# Enter the Amount in Rs:  500
# 500 Rs Debited To your account
# Welcome to ATM Simulator
# Choose :
#     1.Check Balance
#     2.Withdraw
#     3.Deposite
#     4.Exit
# Enter Choice :  1
# Your Balance is : 9500
# Welcome to ATM Simulator
# Choose :
#     1.Check Balance
#     2.Withdraw
#     3.Deposite
#     4.Exit
# Enter Choice :  3
# Enter the Amount Deposite  10000
# 10000 Rs. Credited to your account
# Welcome to ATM Simulator
# Choose :
#     1.Check Balance
#     2.Withdraw
#     3.Deposite
#     4.Exit
# Enter Choice :  1
# Your Balance is : 19500
# Welcome to ATM Simulator
# Choose :
#     1.Check Balance
#     2.Withdraw
#     3.Deposite
#     4.Exit
# Enter Choice :  4

# %%
# 1. Greeting Method

# Create a class Person.

# Method:

# greet()

class Welcome:
    def __init__(self , name):
        self.name  = name 
        self.greet()
    def greet(self):
        print(f"Welcome {self.name}!")
a = Welcome("Dhruv")
# Out:
# Welcome Dhruv!

# %%
# 2. Car Method

# Create a class Car.

# Method:

# start_engine()
class Car:
    def __init__(self):
        self.engine = False
    def start_engine(self) :
        self.engine = True
        print("Engine Started ! ")

c1 = Car()
c1.start_engine()
# Out:
# Engine Started !

# %%
# 3. Student Method

# Create a class Student.

# Attributes:

# name

# Method:

# introduce()
class Student():
    def __init__(self , name , standard):
        self.name = name
        self.standard = standard

    def introduce(self):
        print("Student Name : " , self.name)
        print("Student Standard : " , self.standard)
c = Student("dhruv" , "12th")
c.introduce()
# Out:
# Student Name :  dhruv
# Student Standard :  12th

# %%
# 4. Dog Class

# Create a class Dog.

# Attributes:

# name

# Method:
# bark()
class Dog:
    def __init__(self , name ):
        self.name = name 
    def bark(self):
        print(f"{self.name} is barking")
d = Dog("brodiee")
d.bark()
# Out:
# brodiee is barking

# %%
# 5. Mobile Class

# Create a class Mobile.

# Attributes:

# brand

# Method:

# show_brand()

class Mobile:
    def __init__(self , brand):
        self.brand = brand

    def show_brand(self):
        print("Mobile Brand is : " , self.brand)
m = Mobile("lenovo")
m.show_brand()
# Out:
# Mobile Brand is :  lenovo

# %%
# Employee Class

# Attributes:

# name
# salary

# Method:

# display_details()
class Employee:
    def __init__(self , name , salary):
        self.name = name
        self.salary = salary
    def display_details(self):
        print("Employee Name : " , self.name)
        print("Employee Salary : " , self.salary)
k = Employee("Dhruv" , 30000)
k.display_details()
# Out:
# Employee Name :  Dhruv
# Employee Salary :  30000

# %%
# Circle Class

# Attribute:

# radius

# Method:

# calculate_area()
class Circle:
    def __init__(self , radius ) :
        self.radius = radius
    def calculate_area(self):
        print("Area is : " , 3.14 * self.radius * self.radius)
c = Circle(5)
c.calculate_area()
# Out:
# Area is :  78.5

# %%
# Temperature Converter

# Create a class Temperature.

# Method:

# celsius_to_fahrenheit()

# Formula:

# F=
# 5
# 9
# 	​

# C+32
class Temperature:
    def __init__(self , celsius):
        self.celsius = celsius
    def celsius_to_fahrenheit(self):
        print("Fahrenheit is : " , ((9*self.celsius)/5) + 32)
t = Temperature(24)
t.celsius_to_fahrenheit()
# Out:
# Fahrenheit is :  75.2

# %%
# Product Class

# Attributes:

# product_name
# price

# Methods:

# apply_discount(percent)
# show_price()

class Product:
    def __init__(self , name , price ) :
        self.name = name
        self.price = price 
    def apply_discount(self,percent):
        self.discount = (self.price * percent )/100
    def show_price(self):
        print("Final Price After Discount is : " , self.price - self.discount ) 
p = Product("biscuit" , 65  )
p.apply_discount(10)
p.show_price()
# Out:
# Final Price After Discount is :  58.5

# %%
# Library Management System

# Create a class Library.

# Attributes:

# books (list)

# Methods:

# add_book()
# remove_book()
# show_books()

# Sample Menu:

# 1. Add Book
# 2. Remove Book
# 3. Show Books
# 4. Exit
class Library:
    def __init__(self , books):
        self.books = books
        self.menu()
    def add_book(self):
        name = input("Enter book name : " )
        self.books.append(name)
        print("Book Added Successfully")
    def remove_book(self):
        name = input("Enter book name : " )
        self.books.remove(name)
        print("Book Removed Successfully")
    def show_books(self):
        print("Books Are : " , self.books)
    def menu(self):
        while True:
            try:
                choice = int(input("Choice : \n    1.Add Book\n    2.Remove Book\n    3.Show Books\n    4.Exit\nEnter Choice :"))
                if choice == 1:
                    self.add_book()
                elif choice == 2:
                    self.remove_book()
                elif choice == 3:
                    self.show_books()
                elif choice == 4:
                    break
                else:
                    print("Invalid Choice")
            except ValueError:
                print("Please Enter a Valid Number")
l = Library(["All is well"])
# Out:
# Choice :
#     1.Add Book
#     2.Remove Book
#     3.Show Books
#     4.Exit
# Enter Choice : 1
# Enter book name :  hey
# Book Added Successfully
# Choice :
#     1.Add Book
#     2.Remove Book
#     3.Show Books
#     4.Exit
# Enter Choice : 2
# Enter book name :  hey
# Book Removed Successfully
# Choice :
#     1.Add Book
#     2.Remove Book
#     3.Show Books
#     4.Exit
# Enter Choice : 3
# Books Are :  ['All is well']
# Choice :
#     1.Add Book
#     2.Remove Book
#     3.Show Books
#     4.Exit
# Enter Choice : 4
