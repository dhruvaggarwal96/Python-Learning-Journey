# %% [markdown]
# Day 24 – Bar Charts 📊
#
#
# 📖 What is a Bar Chart?
#
# A bar chart is used to compare values across different categories.
#
# Examples:
#
# Product sales
# Student marks
# Department employees
# Monthly expenses

# %%
import matplotlib.pyplot as plt

products = ["A", "B", "C", "D"]
sales = [500, 700, 300, 900]

plt.bar(products , sales)

plt.title("Product Sales")
plt.xlabel("Products")
plt.ylabel("Sales")

plt.show()

# %%
students = ["Rahul", "Aman", "Priya", "Riya"]
marks = [85, 92, 78, 88]

plt.bar(students , marks)

plt.title("Students Marks" )
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
departments = ["HR", "IT", "Sales", "Finance"]
employees = [12, 35, 25, 18]

plt.bar(departments , employees)

plt.title("Department-Wise Employees")
plt.xlabel("Departments")
plt.ylabel("Number of Employees")

plt.show()

# %%
# Create a bar chart for monthly expenses.
months = ["Jan", "Feb", "Mar", "Apr"]
expenses = [10000, 12000, 9000, 15000]

plt.bar(months , expenses)
plt.title("Monthly Expenses")
plt.xlabel("Months")
plt.ylabel("Expenses")

plt.show()

# %%
# Create a bar chart for website visitors.
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
visitors = [120, 150, 180, 140, 200]

plt.bar(days , visitors)
plt.title("Visitors Chart")
plt.xlabel("Days")
plt.ylabel("Visitors")

plt.show()

# %%
# Create a bar chart for mobile brands sold.
brands = ["Samsung", "Apple", "OnePlus", "Xiaomi"]
sold = [40, 25, 18, 32]

plt.bar(brands , sold)
plt.title("Mobile Sales")
plt.xlabel("Brands")
plt.ylabel("sold")

plt.show()
